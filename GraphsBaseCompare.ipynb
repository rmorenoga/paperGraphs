# %% [markdown]
# # External Function

# %%
# %run ./plotFunctions.py

# %% [markdown]
# # Last Gen Boxplot Grouped

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8']
compareBases(['cuboidBase','flatBase'],folders,'evolBase',20,True,'box','baseCompare')
# Out:
# KruskalResult(statistic=0.12281088371797705, pvalue=0.7260056315452731)

# %% [markdown]
# # Last Gen BoxPlot

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8']
compareBases(['cuboidBase','flatBase'],folders,'evol',20,True,'box','baseCompareInd')
# Out:
# KruskalResult(statistic=135.1848001784215, pvalue=2.043514953567547e-21)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # nModules all Gen Grouped

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8']
compareBases(['cuboidBase','flatBase'],folders,'nModulesBase',20,True,'box','baseCompare')
# Out:
# KruskalResult(statistic=12.959735132131797, pvalue=0.0003182622038485156)

# %% [markdown]
# # nModules all Gen

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8']
compareBases(['cuboidBase','flatBase'],folders,'nModules',20,True,'box','baseCompareInd')
# Out:
# KruskalResult(statistic=184.7730005159552, pvalue=2.5863397940450372e-31)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # BrokenConn all Gen Grouped

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8']
compareBases(['cuboidBase','flatBase'],folders,'brokenConnBase',20,True,'strip','baseCompare')
# Out:
# KruskalResult(statistic=17.099920193573382, pvalue=3.546379510325649e-05)

# %% [markdown]
# # BrokenConn all Gen

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8']
compareBases(['cuboidBase','flatBase'],folders,'brokenConn',20,True,'strip','baseCompareInd')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# KruskalResult(statistic=214.57151034637724, pvalue=2.289021684322e-37)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # nConn last Gen Grouped

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8']
compareBases(['cuboidBase','flatBase'],folders,'nConnBase',20,True,'box','baseCompare')
# Out:
# KruskalResult(statistic=12.959735132131797, pvalue=0.0003182622038485156)

# %% [markdown]
# # nConn last gen

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8']
compareBases(['cuboidBase','flatBase'],folders,'nConn',20,True,'box','baseCompareInd')
# Out:
# KruskalResult(statistic=184.7730005159552, pvalue=2.5863397940450372e-31)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
