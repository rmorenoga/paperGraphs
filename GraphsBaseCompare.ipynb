# %% [markdown]
# # External Function

# %%
# %run ./plotFunctions.py

# %% [markdown]
# # Last Gen Boxplot Grouped

# %%
folders = ['1','1_25','1_5','1_75','2','4','C1-1_25-1_5-1_75-2']
compareBases(['flatBase','filesFromLenghtExperiment'],folders,'evolBase',10,True,'box')
# Out:
# KruskalResult(statistic=4.624507164568001, pvalue=0.03151831477669611)

# %% [markdown]
# # Last Gen BoxPlot

# %%
folders = ['1','1_25','1_5','1_75','2','4','C1-1_25-1_5-1_75-2']
compareBases(['flatBase','filesFromLenghtExperiment'],folders,'evol',10,True,'box')
# Out:
# KruskalResult(statistic=30.298358662613964, pvalue=0.004264888118021654)

# %% [markdown]
# # nModules all Gen Grouped

# %%
folders = ['1','1_25','1_5','1_75','2','4','C1-1_25-1_5-1_75-2']
compareBases(['flatBase','filesFromLenghtExperiment'],folders,'nModulesBase',10,True,'box')
# Out:
# KruskalResult(statistic=8.775559566558421, pvalue=0.0030529348756547295)

# %% [markdown]
# # nModules all Gen

# %%
folders = ['1','1_25','1_5','1_75','2','4','C1-1_25-1_5-1_75-2']
compareBases(['flatBase','filesFromLenghtExperiment'],folders,'nModules',10,False,'box')
# Out:
# KruskalResult(statistic=2860.1999188616282, pvalue=0.0)

# %% [markdown]
# # BrokenConn all Gen Grouped

# %%
folders = ['1','1_25','1_5','1_75','2','4','C1-1_25-1_5-1_75-2']
compareBases(['flatBase','filesFromLenghtExperiment'],folders,'brokenConnBase',10,True,'strip')
# Out:
# KruskalResult(statistic=0.3648285097003061, pvalue=0.5458367572949145)

# %% [markdown]
# # BrokenConn all Gen

# %%
folders = ['1','1_25','1_5','1_75','2','4','C1-1_25-1_5-1_75-2']
compareBases(['flatBase','filesFromLenghtExperiment'],folders,'brokenConn',10,False,'strip')
# Out:
# KruskalResult(statistic=8422.728755155646, pvalue=0.0)
