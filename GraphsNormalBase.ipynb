# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import json
import re
import csv
import scipy.stats as scp_stats
import scikit_posthocs as sp

#plt.rc('text', usetex=True)
#plt.rc('font', family='serif',size ='16')
pd.options.display.max_rows = 4000
#matplotlib.rcParams['ps.useafm'] = True
#matplotlib.rcParams['text.usetex'] = True

# %% [markdown]
# # External Functions

# %%
# %run ./statannot.py
# %run ./plotFunctions.py

# %% [markdown]
# # All Evolution Individual graphs

# %%
folders = ['1','1_25','1_5','1_75','2','C1-1_25-1_5-1_75-2','4','8','C1-8']     
plotResultGraphs('filesFromLenghtExperiment',folders,'evol',10,True)

# %% [markdown]
# # Compare evolutions (Put folders to compare in folders array)

# %%
folders = ['1','1_25','1_5','1_75']   #,'2','1-1_25-1_5-1_75-2'
plotResultGraphs('filesFromLenghtExperiment',folders,'evol',10,False)

# %% [markdown]
# # Last Gen BoxPlot

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','C1-1_25-1_5-1_75-2','C1-8']
boxplotResults('filesFromLenghtExperiment',folders,'evol',10,False,True,'box')
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 1_75 v.s. 1_5: Mann-Whitney-Wilcoxon test two-sided P_val=9.698e-01 U_stat=5.000e+01
# KruskalResult(statistic=34.86945054945056, pvalue=2.8242828605887343e-05)

# %% [markdown]
# # Compare all nModules trough all generations in boxplot

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','C1-1_25-1_5-1_75-2','C1-8']
boxplotResults('filesFromLenghtExperiment',folders,'nModules',10,False,False,'box')
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 1_75 v.s. 1_5: Mann-Whitney-Wilcoxon test two-sided P_val=2.520e-04 U_stat=2.577e+05
# KruskalResult(statistic=3462.22334257879, pvalue=0.0)

# %% [markdown]
# # All Number of Modules Individual graphs

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','C1-8']     
plotResultGraphs('filesFromLenghtExperiment',folders,'nModules',10,True)

# %% [markdown]
# # Compare nModules (Put folders to compare in folders array)

# %%
folders = ['1','1_25','1_5','1_75','2','C1-1_25-1_5-1_75-2']   
plotResultGraphs('filesFromLenghtExperiment',folders,'nModules',10,False)

# %% [markdown]
# # Compare brokenConn trough all generations in boxplot

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','C1-1_25-1_5-1_75-2','C1-8']
boxplotResults('filesFromLenghtExperiment',folders,'brokenConn',10,False,False,'strip')
# Out:
# KruskalResult(statistic=5109.584982963531, pvalue=0.0)

# %% [markdown]
# # All broken connections Individual graphs

# %%
folders = ['1','2','4','8','C1-8']     
plotResultGraphs('filesFromLenghtExperiment',folders,'brokenConn',10,True)

# %% [markdown]
# # Compare broken connections (Put folders to compare in folders array)

# %%
folders = ['1','2','4','8','C1-8']   
plotResultGraphs('filesFromLenghtExperiment',folders,'brokenConn',10,False)

# %% [markdown]
# # 4ModuleInit Evolution Compare

# %%
folders = ['1','2','1-2']  
plotResultGraphs('4ModuleInit',folders,'evol',10,False)
