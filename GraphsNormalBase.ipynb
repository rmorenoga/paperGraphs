# %% [markdown]
# # External Functions

# %%
# %run ./plotFunctions.py

# %% [markdown]
# # All Evolution Individual graphs

# %%
folders = ['1','1_5','1_25','1_75','2','4','8','1-8']     
#plotResultGraphs('cuboidBase',folders,'evol',20,True)
plotResultGraphsEval('cuboidBase',folders,'evol',20,True,25000,'cuboidBase')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %% [markdown]
# # Compare evolutions (Put folders to compare in folders array)

# %%
folders = ['1','2','4','8']  #,'2','1-1_25-1_5-1_75-2'
#plotResultGraphs('cuboidBase',folders,'evol',20,False)
plotResultGraphsEval('cuboidBase',folders,'evol',20,False,25000,'cuboidBase')
# Out:
# C:\Users\golde_000\Google Drive\2019\Papers\Base Length\plotFunctions.py:218: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig(saveFile+tp+'plot.png',bbox_inches="tight")

# %% [markdown]
# # Last Gen BoxPlot

# %%
folders =  ['1','1_25','1_5','1_75','2','4','8','1-8']
boxPairs = [("1","4"),("1_75","2"),("2","4")]
boxplotResults('cuboidBase',folders,'evol',20,False,True,'box','cuboidLastGen',boxPairs)
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 1 v.s. 4: Mann-Whitney-Wilcoxon test two-sided P_val=2.748e-02 U_stat=2.820e+02
# 1_75 v.s. 2: Mann-Whitney-Wilcoxon test two-sided P_val=2.227e-02 U_stat=2.850e+02
# 2 v.s. 4: Mann-Whitney-Wilcoxon test two-sided P_val=9.209e-04 U_stat=3.230e+02
# KruskalResult(statistic=68.8443896850489, pvalue=2.5287022264211225e-12)

# %% [markdown]
# # Compare all nModules trough all generations in boxplot

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8']
boxPairs = [("1","2"),("1_5","1-8"),("2","4")]
boxplotResults('cuboidBase',folders,'nModules',20,False,True,'box','cuboidLastGen',boxPairs)
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 1 v.s. 2: Mann-Whitney-Wilcoxon test two-sided P_val=5.710e-03 U_stat=3.015e+02
# 1_5 v.s. 1-8: Mann-Whitney-Wilcoxon test two-sided P_val=4.831e-02 U_stat=2.730e+02
# 2 v.s. 4: Mann-Whitney-Wilcoxon test two-sided P_val=1.386e-05 U_stat=3.595e+02
# KruskalResult(statistic=83.58061735901624, pvalue=2.5582018053486683e-15)

# %% [markdown]
# # All Number of Modules Individual graphs

# %%
folders = ['1','2','4','8']      
#plotResultGraphs('cuboidBase',folders,'nModules',20,True)
plotResultGraphsEval('cuboidBase',folders,'nModules',20,True,25000)

# %% [markdown]
# # Compare nModules (Put folders to compare in folders array)

# %%
folders = ['1','2','4','8']    
#plotResultGraphs('cuboidBase',folders,'nModules',20,False)
plotResultGraphsEval('cuboidBase',folders,'nModules',20,False,25000)

# %% [markdown]
# # Compare brokenConn trough all generations in boxplot

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8'] 
boxPairs = [("1","2"),("1_5","1-8"),("2","4")]
boxplotResults('cuboidBase',folders,'brokenConn',20,False,True,'strip','cuboidLastGen',boxPairs)
# Out:
# KruskalResult(statistic=105.81982069586174, pvalue=6.751418417439276e-20)

# %% [markdown]
# # All broken connections Individual graphs

# %%
folders = ['1','2','4','8']     
#plotResultGraphs('cuboidBase',folders,'brokenConn',20,True)
plotResultGraphsEval('cuboidBase',folders,'brokenConn',20,True,25000)

# %% [markdown]
# # Compare broken connections (Put folders to compare in folders array)

# %%
folders = ['1','2','4','8']   
#plotResultGraphs('cuboidBase',folders,'brokenConn',20,False)
plotResultGraphsEval('cuboidBase',folders,'brokenConn',20,False,25000)

# %% [markdown]
# # 4ModuleInit Evolution Compare

# %%
folders = ['1','2','1-2']  
plotResultGraphs('4ModuleInit',folders,'evol',10,False)

# %% [markdown]
# # nConnections per module LastGen

# %%
folders = ['1','1_25','1_5','1_75','2','4','8','1-8'] 
boxPairs = [("1","2"),("1_5","1-8"),("2","4")]
boxplotResults('cuboidBase',folders,'nConn',20,False,True,'box','cuboidLastGen',boxPairs)
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 1 v.s. 2: Mann-Whitney-Wilcoxon test two-sided P_val=5.710e-03 U_stat=3.015e+02
# 1_5 v.s. 1-8: Mann-Whitney-Wilcoxon test two-sided P_val=4.831e-02 U_stat=2.730e+02
# 2 v.s. 4: Mann-Whitney-Wilcoxon test two-sided P_val=1.386e-05 U_stat=3.595e+02
# KruskalResult(statistic=83.58061735901624, pvalue=2.5582018053486683e-15)
