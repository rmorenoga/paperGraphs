# %% [markdown]
# # External Functions

# %%
# %run ./plotFunctions.py

# %% [markdown]
# # Evolution Individual Graphs

# %%
folders = ['1','1_5','1_25','1_75','2','4','8']    
#plotResultGraphs('flatBase',folders,'evol',20,True)
plotResultGraphsEval('flatBase',folders,'evol',20,True,25000,'flatBase')
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %% [markdown]
# # Evolution Compare

# %%
folders = ['1','1_5','1_25','1_75','2','4','8']      
#plotResultGraphs('flatBase',folders,'evol',20,False)
plotResultGraphsEval('flatBase',folders,'evol',20,False,25000,'flatBase')
# Out:
# C:\Users\golde_000\Google Drive\2019\Papers\Base Length\plotFunctions.py:208: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   #lastGen: plot only lastGen data or all data

# %% [markdown]
# # LastGen BoxPlot

# %%
folders = ['1','1_5','1_25','1_75','2','4','8']      
boxplotResults('flatBase',folders,'evol',20,False,True,'box','flatLastGen')
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2 v.s. 4: Mann-Whitney-Wilcoxon test two-sided P_val=1.294e-04 U_stat=3.420e+02
# KruskalResult(statistic=63.23702127659584, pvalue=9.875555976959555e-12)

# %% [markdown]
# # Broken Connections all Gen

# %%
folders = ['1','1_5','1_25','1_75','2','4','8'] 
boxplotResults('flatBase',folders,'brokenConn',20,False,True,'strip','flatLastGen')
# Out:
# KruskalResult(statistic=100.5494206995954, pvalue=1.927135749675736e-19)

# %% [markdown]
# # nModules all Gen

# %%
folders = ['1','1_5','1_25','1_75','2','4','8']
boxplotResults('flatBase',folders,'nModules',20,False,True,'box','flatLastGen')
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2 v.s. 4: Mann-Whitney-Wilcoxon test two-sided P_val=6.877e-06 U_stat=3.650e+02
# KruskalResult(statistic=83.60031946831977, pvalue=6.434563385232779e-16)

# %% [markdown]
# # Plot Intertia individual graphs

# %%
folders = ['1','1_5','1_25','1_75','2','4','8']
plotInertiaGraphs('flatBase',folders,'evol',20,True,25000)

# %% [markdown]
# # nConnections per module LastGen

# %%
folders = ['1','1_5','1_25','1_75','2','4','8']
boxplotResults('flatBase',folders,'nConn',20,False,True,'box','flatLastGen')
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2 v.s. 4: Mann-Whitney-Wilcoxon test two-sided P_val=6.877e-06 U_stat=3.650e+02
# KruskalResult(statistic=83.60031946831977, pvalue=6.434563385232779e-16)
