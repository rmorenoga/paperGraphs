# %% [markdown]
# # External Functions

# %%
# %run ./plotFunctions.py

# %% [markdown]
# # Evolution Individual Graphs

# %%
folders = ['1','1_25','1_5','1_75','2','C1-1_25-1_5-1_75-2']     
plotResultGraphs('flatBase',folders,'evol',10,True)

# %% [markdown]
# # Evolution Compare

# %%
folders = ['1','1_25','1_5','1_75']     
plotResultGraphs('flatBase',folders,'evol',10,False)

# %% [markdown]
# # LastGen BoxPlot

# %%
folders = ['1','1_25','1_5','1_75','2','4','C1-1_25-1_5-1_75-2']
boxplotResults('flatBase',folders,'evol',10,False,True,'box')
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 1_75 v.s. 1_5: Mann-Whitney-Wilcoxon test two-sided P_val=4.727e-01 U_stat=4.000e+01
# KruskalResult(statistic=13.747122736418532, pvalue=0.032592097178679315)

# %% [markdown]
# # Broken Connections all Gen

# %%
folders = ['1','1_25','1_5','1_75','2','4','C1-1_25-1_5-1_75-2']
boxplotResults('flatBase',folders,'brokenConn',10,False,False,'strip')
# Out:
# KruskalResult(statistic=3194.9885563914177, pvalue=0.0)

# %% [markdown]
# # nModules all Gen

# %%
folders = ['1','1_25','1_5','1_75','2','4','C1-1_25-1_5-1_75-2']
boxplotResults('flatBase',folders,'nModules',10,False,False,'box')
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 1_75 v.s. 1_5: Mann-Whitney-Wilcoxon test two-sided P_val=3.752e-03 U_stat=3.216e+05
# KruskalResult(statistic=1002.171571270628, pvalue=3.0320469251977084e-213)

# %% [markdown]
# # Plot Intertia individual graphs

# %%
folders = ['1','1_25','1_5','1_75','2','4','C1-1_25-1_5-1_75-2']
plotInertiaGraphs('flatBase',folders,'evol',10,True)
