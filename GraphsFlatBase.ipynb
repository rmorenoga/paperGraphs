# %% [markdown]
# # External Functions

# %%
# %run ./plotFunctions.py

# %% [markdown]
# # Evolution Individual Graphs

# %%
folders = ['1','1_5','1_25','1_75','2','4','8','1-8']    
#plotResultGraphs('flatBase',folders,'evol',20,True)
plotResultGraphsEval('flatBase',folders,'evol',20,True,25000,'flatBase')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %% [markdown]
# # Evolution Compare

# %%
folders = ['1','2','4','8']      
#plotResultGraphs('flatBase',folders,'evol',20,False)
plotResultGraphsEval('flatBase',folders,'evol',20,False,25000,'flatBase')
# Out:
# C:\Users\golde_000\Google Drive\2019\Papers\Base Length\plotFunctions.py:218: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig(saveFile+tp+'plot.png',bbox_inches="tight")
# C:\Users\golde_000\Anaconda3\envs\paperGraphs\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # LastGen BoxPlot

# %%
folders = ['1','1_5','1_25','1_75','2','4','8','1-8'] 
boxPairs = [("2","4")]
boxplotResults('flatBase',folders,'evol',20,False,True,'box','flatLastGen',boxPairs)
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2 v.s. 4: Mann-Whitney-Wilcoxon test two-sided P_val=1.294e-04 U_stat=3.420e+02
# KruskalResult(statistic=65.46400621118005, pvalue=1.2131731771348253e-11)

# %% [markdown]
# # Broken Connections all Gen

# %%
folders = ['1','1_5','1_25','1_75','2','4','8','1-8'] 
boxPairs = [("1","2"),("1_5","1-8"),("2","4")]
boxplotResults('flatBase',folders,'brokenConn',20,False,True,'strip','flatLastGen',boxPairs)
# Out:
# KruskalResult(statistic=105.57741130743996, pvalue=7.578635838489011e-20)

# %% [markdown]
# # nModules all Gen

# %%
folders = ['1','1_5','1_25','1_75','2','4','8','1-8']
boxPairs = [("2","4"),("2","1-8")]
boxplotResults('flatBase',folders,'nModules',20,False,True,'box','flatLastGen',boxPairs)
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2 v.s. 4: Mann-Whitney-Wilcoxon test two-sided P_val=6.877e-06 U_stat=3.650e+02
# 2 v.s. 1-8: Mann-Whitney-Wilcoxon test two-sided P_val=3.351e-03 U_stat=3.080e+02
# KruskalResult(statistic=94.21572038524856, pvalue=1.681257631420388e-17)

# %% [markdown]
# # Plot Intertia individual graphs

# %%
folders = ['1','1_5','1_25','1_75','2','4','8','1-8']
plotInertiaGraphs('flatBase',folders,'evol',20,True,25000)

# %% [markdown]
# # nConnections per module LastGen

# %%
folders = ['1','1_5','1_25','1_75','2','4','8','1-8']
boxPairs = [("2","4"),("2","1-8")]
boxplotResults('flatBase',folders,'nConn',20,False,True,'box','flatLastGen',boxPairs)
# Out:
# pvalue annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 2 v.s. 4: Mann-Whitney-Wilcoxon test two-sided P_val=6.877e-06 U_stat=3.650e+02
# 2 v.s. 1-8: Mann-Whitney-Wilcoxon test two-sided P_val=3.351e-03 U_stat=3.080e+02
# KruskalResult(statistic=94.21572038524856, pvalue=1.681257631420388e-17)
